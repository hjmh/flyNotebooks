# %% [markdown]
# ## Visualisation of how landmark size and fog affect landmark visibility in the VR

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import getcwd

# %matplotlib inline

# %%
def myAxisTheme(myax):
    myax.get_xaxis().tick_bottom()
    myax.get_yaxis().tick_left()
    myax.spines['top'].set_visible(False)
    myax.spines['right'].set_visible(False)

# %%
# Set landmark dimensions in mm
LMwidth = 8
LMheight = 30

# Set maximum and minimum landmark distances to be cosidered (mm)
minDist = 0
maxDist = 60

# Set virtual fog parameter (minumum bound and upper bound)
minFog = 30
maxFog = 45

# Display size (pixels)
screenWidth = 720
screenHeight = 1280

# %%
nPts = 1 # number of points per mm

distRange = np.linspace(minDist,maxDist,(maxDist-minDist+1)*nPts)

# %%
# Visibility through virtual fog
maxVis = float(max(maxDist-maxFog, maxDist))
maxVisFog = float(min(maxFog, maxDist))

visibility = np.concatenate((100.0*np.ones((minFog-minDist)*nPts),
                             100.0 - np.linspace(0,100.0*((maxVisFog-minFog)/(maxFog-minFog)),(maxVisFog-minFog+1)*nPts),
                             0*np.ones((maxVis-maxVisFog)*nPts)))

# %%
# Size of landmark
angleWidth = lambda x: 180/np.pi * 2*np.arctan((LMwidth/2.0)/x)
angleHeight = lambda x: 180/np.pi * np.arctan((LMheight)/x)

alphaWidth = angleWidth(distRange)
alphaHeight = angleHeight(distRange)

# %%
LMappearanceFig = plt.figure(figsize=(8,5))
LMappearancePlot = LMappearanceFig.add_subplot(111)

LMappearancePlot.plot(distRange, visibility, color='steelblue', linewidth=2)
LMappearancePlot.plot(distRange,alphaWidth, color='black', linewidth= 2)
LMappearancePlot.plot(distRange,alphaHeight, color='grey', linewidth= 2)

LMappearancePlot.axhline(y=20,linestyle='dashed',color='black')

LMappearancePlot.axvline(x=LMwidth/2,linestyle='dashed',color='black')

LMappearancePlot.set_ylim(-10,180)
LMappearancePlot.set_xlabel('Landmark distance [mm]')
LMappearancePlot.set_ylabel('Landmark visibility [%]\nLandmark width and height [deg]')
leg = LMappearancePlot.legend(['Visibility', 'Landmark width','Landmark height'])
leg.get_frame().set_linewidth(0.0)
myAxisTheme(LMappearancePlot)

# %% [markdown]
# ## Add reinforcement

# %%
maxR = 50
blR = 10
rR = 15

# %%
# Profile of reinforcement level 
maxrR = float(min(rR, maxDist))

profileR = np.concatenate((maxR - np.linspace(0,maxR*(maxrR/rR)-blR,(maxrR+1)*nPts),
                           blR*np.ones((maxDist-rR)*nPts)))

# %%
profileR[np.where(distRange==LMwidth/2)[0]]
# Out:
# array([ 39.33333333])

# %%
LMappearanceFig = plt.figure(figsize=(10,6))
LMappearancePlot = LMappearanceFig.add_subplot(111)

LMappearancePlot.plot(distRange, visibility, color='steelblue', linewidth=2)
LMappearancePlot.plot(distRange,alphaWidth, color='black', linewidth= 2)
LMappearancePlot.plot(distRange,alphaHeight, color='grey', linewidth= 2)
LMappearancePlot.plot(distRange,profileR, color='tomato', linewidth= 2)

LMappearancePlot.plot(distRange, visibility[::-1], color='steelblue', linewidth=2, linestyle='dashed')

LMappearancePlot.axhline(y=20,linestyle='dashed',color='black')
LMappearancePlot.axhline(y=80,linestyle='dashed',color='grey')
LMappearancePlot.axhline(y=120,linestyle='dashed',color='black')

LMappearancePlot.axvline(x=LMwidth/2,linestyle='dashed',color='black')

LMappearancePlot.set_ylim(-10,180)
LMappearancePlot.set_xlabel('Landmark distance [mm]')
LMappearancePlot.set_ylabel('Landmark visibility [%]\nLandmark width and height [deg]')
leg = LMappearancePlot.legend(['Visibility', 'Landmark width','Landmark height','Reinforcement level'])
leg.get_frame().set_linewidth(0.0)
myAxisTheme(LMappearancePlot)

# %% [markdown]
# ## Interactive plot

# %%
from bokeh.io import output_notebook, push_notebook, push
from bokeh.layouts import widgetbox, row
from bokeh.models import CustomJS,Slider 
from bokeh.plotting import figure, output_file, show, ColumnDataSource

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0f77c23b-e838-413b-ac1e-af4d20609f3c">Loading BokehJS ...</span>
#     </div>

# %%
x=np.linspace(minDist,maxDist,(maxDist-minDist)*nPts)
y1=angleWidth(x)
y2=angleHeight(x)

vissource = ColumnDataSource(data=dict(x=x,y1=y1,y2=y2))

visplot = figure(y_range=(-10,180), x_range=(minDist, maxDist), plot_width=600,plot_height=400)

visplot.line('x','y1',source=vissource,line_width=2, color='black')
visplot.line('x','y2',source=vissource,line_width=2, color='grey')


callback = CustomJS(args=dict(source=vissource),code="""
    var data = source.data;
    var lmw = width.value;
    var lmh = height.value;
    
    x = data['x']
    y1 = data['y1']
    y2 = data['y2']
    
    for (i = 0; i < x.length; i++) {
        y1[i] = 180/Math.PI * 2*Math.atan((lmw/2.0)/x[i]);
        y2[i] = 180/Math.PI * Math.atan((lmh)/x[i]);
    }
    source.trigger('change');
""")

width_slider = Slider(start=0.5,end=20,value=10,step=0.5,title="Landmark width [mm]",callback=callback)
callback.args["width"] = width_slider

height_slider = Slider(start=1,end=60,value=40,step=1,title="Landmark height [mm]",callback=callback)
callback.args["height"] = height_slider

layout = row(
    visplot,
    widgetbox(width_slider, height_slider)
)

lohandle = show(layout, notebook_handle=True)

#visplot.title = 'Landmark size'
visplot.yaxis.axis_label = 'Angular size [deg]'
visplot.xaxis.axis_label = 'Landmark distance [mm]'
push_notebook(handle=lohandle)

push(handle = lohandle)
output_file('LandmarkSizePlot', title='Angular landmark size', mode='relative', root_dir=getcwd())
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1a11036f-d40f-4139-981a-f89dbc6e710f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1a11036f-d40f-4139-981a-f89dbc6e710f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("2a962ebd-240b-4847-a6db-297690fb8e22", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1a11036f-d40f-4139-981a-f89dbc6e710f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1a11036f-d40f-4139-981a-f89dbc6e710f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5cda62ba-4442-478c-9ce8-ee964eb00116":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y1"}},"id":"7e7f81fa-8cb5-4051-8645-b5909ce92d69","type":"Line"},{"attributes":{"callback":null,"end":60},"id":"826210f6-94b5-4911-b0e6-555e73fb1437","type":"Range1d"},{"attributes":{"children":[{"id":"98a9e9f6-0f28-40c1-bbb3-da395dbf16d5","type":"Slider"},{"id":"4ba8b53c-a350-46c9-ac83-85bb59e2ca53","type":"Slider"}]},"id":"fa436cbe-7c2b-426e-8340-ce28360e7170","type":"WidgetBox"},{"attributes":{"callback":{"id":"0b7a4451-d4f2-402a-97a9-a137897b2bf8","type":"CustomJS"},"end":60,"start":1,"step":1,"title":"Landmark height [mm]","value":40},"id":"4ba8b53c-a350-46c9-ac83-85bb59e2ca53","type":"Slider"},{"attributes":{"children":[{"id":"db5b81b1-e9bd-4c45-b5b6-fcf9d31fd172","subtype":"Figure","type":"Plot"},{"id":"fa436cbe-7c2b-426e-8340-ce28360e7170","type":"WidgetBox"}]},"id":"957610f2-f7ff-4c9f-90b9-3b7f37a06de2","type":"Row"},{"attributes":{},"id":"5dcea262-aeef-4bb6-a9b7-6dd4c0464f5b","type":"BasicTickFormatter"},{"attributes":{"args":{"height":{"id":"4ba8b53c-a350-46c9-ac83-85bb59e2ca53","type":"Slider"},"source":{"id":"ef856133-3237-4386-8f3f-a7602be0c9ef","type":"ColumnDataSource"},"width":{"id":"98a9e9f6-0f28-40c1-bbb3-da395dbf16d5","type":"Slider"}},"code":"\n    var data = source.data;\n    var lmw = width.value;\n    var lmh = height.value;\n    \n    x = data['x']\n    y1 = data['y1']\n    y2 = data['y2']\n    \n    for (i = 0; i < x.length; i++) {\n        y1[i] = 180/Math.PI * 2*Math.atan((lmw/2.0)/x[i]);\n        y2[i] = 180/Math.PI * Math.atan((lmh)/x[i]);\n    }\n    source.trigger('change');\n"},"id":"0b7a4451-d4f2-402a-97a9-a137897b2bf8","type":"CustomJS"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y2"}},"id":"58fb9677-52ff-4d6c-a1dd-bef4fd089ff4","type":"Line"},{"attributes":{"formatter":{"id":"5dcea262-aeef-4bb6-a9b7-6dd4c0464f5b","type":"BasicTickFormatter"},"plot":{"id":"db5b81b1-e9bd-4c45-b5b6-fcf9d31fd172","subtype":"Figure","type":"Plot"},"ticker":{"id":"98d6de8a-4b72-4c38-a642-6adc9988f501","type":"BasicTicker"}},"id":"9a73c82b-d56e-46ab-93f2-85cce29bbdf2","type":"LinearAxis"},{"attributes":{"below":[{"id":"9a73c82b-d56e-46ab-93f2-85cce29bbdf2","type":"LinearAxis"}],"left":[{"id":"f74eea78-f58d-4d7b-a904-ad78388fbe85","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"9a73c82b-d56e-46ab-93f2-85cce29bbdf2","type":"LinearAxis"},{"id":"bd91aae9-d122-4997-af32-e40eb88ba4aa","type":"Grid"},{"id":"f74eea78-f58d-4d7b-a904-ad78388fbe85","type":"LinearAxis"},{"id":"1da4917f-1b5b-46a0-8efe-77ef6829e23b","type":"Grid"},{"id":"3c00df2f-e7c1-4031-a657-1d776ad3f8c2","type":"BoxAnnotation"},{"id":"1547751a-4566-4ccf-89cf-174ec7935113","type":"GlyphRenderer"},{"id":"e08184fb-f6c3-4537-90f7-c5006a4788ad","type":"GlyphRenderer"}],"title":{"id":"fc4540a7-cb02-4996-b75f-3a751be93cc8","type":"Title"},"tool_events":{"id":"9c8ef166-461f-4446-b7e4-06e237ecb810","type":"ToolEvents"},"toolbar":{"id":"0903b55a-6cb7-41be-a822-b9314c96707d","type":"Toolbar"},"x_range":{"id":"826210f6-94b5-4911-b0e6-555e73fb1437","type":"Range1d"},"y_range":{"id":"b05b2fc7-ac27-4f0a-829f-09f5f072431b","type":"Range1d"}},"id":"db5b81b1-e9bd-4c45-b5b6-fcf9d31fd172","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"09fe8891-0f93-4a0d-bed7-e0587d19402c","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3c00df2f-e7c1-4031-a657-1d776ad3f8c2","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"db5b81b1-e9bd-4c45-b5b6-fcf9d31fd172","subtype": ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-7694a357199f> in <module>()
#      45 push_notebook(handle=lohandle)
#      46
# ---> 47 push(handle = lohandle)
#      48 output_file('LandmarkSizePlot', title='Angular landmark size', mode='relative', root_dir=getcwd())
#
# TypeError: push() got an unexpected keyword argument 'handle'

# %%
# Landmark size in pixels (if in front of fly)
